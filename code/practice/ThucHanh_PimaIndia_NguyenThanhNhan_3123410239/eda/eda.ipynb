# %% [markdown]
# ## Tải dữ liệu đã tiền xử lý
#
# ### Subtask:
# Tải dữ liệu từ tệp "pima-indians-diabetes_preprocessed.csv" vào DataFrame.

# %% [markdown]
# **Reasoning**:
# Import the pandas library and load the preprocessed data into a DataFrame.

# %%
import pandas as pd

df_preprocessed = pd.read_csv('pima-indians-diabetes_preprocessed.csv')

# %% [markdown]
# ## Hiển thị thông tin cơ bản
#
# ### Subtask:
# Hiển thị thông tin cơ bản về DataFrame, bao gồm các cột, kiểu dữ liệu và các giá trị không thiếu.

# %% [markdown]
# **Reasoning**:
# Display basic information about the dataframe, including column names, data types, and non-null counts, and then calculate the number of missing values per column to understand the data structure and identify missing data.

# %%
df_preprocessed.info()
print(df_preprocessed.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    float64
#  1   Glucose                   767 non-null    float64
#  2   BloodPressure             767 non-null    float64
#  3   SkinThickness             767 non-null    float64
#  4   Insulin                   767 non-null    float64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  767 non-null    float64
#  7   Age                       767 non-null    float64
#  8   Outcome                   767 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# ...

# %% [markdown]
# ## Thống kê mô tả
#
# ### Subtask:
# Tạo bảng thống kê mô tả cho các cột số trong DataFrame.

# %% [markdown]
# **Reasoning**:
# Use the describe method to generate descriptive statistics for numerical columns and display the result.

# %%
description = df_preprocessed.describe()
display(description)
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  7.670000e+02  7.670000e+02     767.000000   7.670000e+02  7.670000e+02
# mean  -1.852784e-17  2.315980e-18       0.000000   3.821367e-17  2.605478e-17
# std    1.000653e+00  1.000653e+00       1.000653   1.000653e+00  1.000653e+00
# min   -1.140579e+00 -2.551388e+00      -4.000057  -2.203247e+00 -7.752721e-01
# 25%   -8.437263e-01 -7.271345e-01      -0.693352  -4.688031e-01 -6.039737e-01
# 50%   -2.500216e-01 -1.519194e-01      -0.032011  -4.688031e-01 -6.039737e-01
# 75%    6.405353e-01  6.040777e-01       0.629330   5.068218e-01  3.048592e-01
# max    3.905911e+00  2.543374e+00       4.101371   7.769806e+00  7.142518e+00
#
#                 BMI  DiabetesPedigreeFunction           Age     Outcome
# count  7.670000e+02              7.670000e+02  7.670000e+02  767.000000
# mean   5.859430e-16             -2.084382e-17  1.598026e-16    0.348110
# ...

# %% [markdown]
# ## Trực quan hóa dữ liệu
#
# ### Subtask:
# Tạo các biểu đồ phù hợp để khám phá phân phối của các biến và mối quan hệ giữa chúng.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries for plotting and create histograms for all numerical columns to visualize their distributions. Then, create a correlation heatmap to visualize the relationships between variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = df_preprocessed.select_dtypes(include=['float64', 'int64']).columns.tolist()

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(df_preprocessed[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.savefig('histograms.png') # Save the histograms plot
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(df_preprocessed.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.savefig('correlation_heatmap.png') # Save the heatmap
plt.show()
